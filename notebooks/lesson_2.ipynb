# %%
print(1,2,3)

# %%
'1 2 3'
# -> 
'1', '2', '3' # Split

# %%
data = input().split()
print(data)

# %%
name, age, city = input('請輸入名字 年齡 城市：').split()
print(name, age, city)

# %%
print(name)
print(age)
print(city)

# %%
a = '1,2,3'.split(',')
a.append(4)
print(a)

# %%
x = 10
print(x)

# %%
x = 10 # 定義變數 x 的值為 10
print(x + 10) # 輸出 x 加上 10 的結果

# %%
print(x)

# %%
first, second = input('請輸入兩個詞，中間用空格隔開：').split()
print('第一個詞：', first)
print('第二個詞：', second)

# %% [markdown]
# input1: '天氣,溫度,雨量,濕度'
# input2: -> '下雨,23,100,20'
#
# print 四個東西

# %%
first, second, third, fourth = input('請輸入四個詞：').split(',')
first_2, second_2, third_2, fourth_2 = input('請輸入四個詞：').split(',')

print(first,":", first_2, '\n',
      second,":", second_2, '\n',
      third,":", third_2, '\n',
      fourth,":", fourth_2)

# %%
out = input('請輸入四個詞：').split(',')

# %%
print(out)

# %%
hello = "Hello, World!"
print(hello)

# %%
10 + 10

# %%
'10' + '10'

# %%
x = 2.41
y = 3.141
z = 5.0 # 注意！小數點後為 0 依然是浮點數
z_2 = 5 # 注意！沒有小數點的 5 是整數

# %%
print(z)
print(z_2)

print(type(z) == type(z))

# %%
x = 10
y = '5.1'
z = True
l = [x, y, z]

print(x)
print(y)
print(z)
print(l)

# %%
x = 10
y = '5.1'
z = True
l = [x, y, z]

print(type(x))
print(type(y))
print(type(z))
print(type(l))

# %%
int("23") + 4 # -> 27

# %%
int(50.9999)

# %%
float(50)

# %%
51 + 0.3 # 51(int) -> 51.0(float) + 0.3(float) -> 51.3(float)

# %%
list('Hello') # "Hello": 6 個字元 -> ['H', 'e', 'l', 'l', 'o']

# %%
bool('False')

# %%
price = 60
count = '2'
total = price * int(count)
print(total)

# %% [markdown]
# 請把 `word1` 和 `word2` 用一個空白接起來。
#
# 請完成下面的函式。
