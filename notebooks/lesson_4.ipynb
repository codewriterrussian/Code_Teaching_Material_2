# %%
print(2 + 3 * 4)
# Out:
# 14

# %% [markdown]
# 1. 布林值 -> True, False
# 2. str -> 布林值 -> True, False
# 3. int/flaot -> 布林值 -> True, False
# 4. 串列 -> 布林值 -> True, False

# %%
name = "Tom"
name_2 = '' # 沒有東西

print(name)
print(name_2)
print(bool(name))
print(bool(name_2)) # 問字串有沒有東西
# Out:
# Tom
#
# True
# False

# %%
num = -1
num_2 = 0


print(num, num_2)
print(bool(num), bool(num_2)) # 1 -> 不是 0； 0 —>  是 0
# Out:
# -1 0
# True False

# %%
list1 = ['hi', 2, 3]
list2 = []

print(list1, list2)
print(bool(list1), bool(list2))
# Out:
# ['hi', 2, 3] []
# True False
