# %% [markdown]
# # Python 基礎練習測驗 Notebook
#
# ## 使用方式
#
# 1. 先執行「自動檢查工具」cell。
# 2. 閱讀每一題的題目。
# 3. 只修改 `# TODO` 附近的答案。
# 4. 每完成一題，就執行該題下面的「檢查」cell。
# 5. 最後執行「總檢查」cell。
#
# 注意：題目主要使用 `return`，不是 `print()`。這樣比較方便自動檢查答案。

# %%
# === 自動檢查工具：請先執行這個 cell，不要修改 ===
import json
import base64

_HIDDEN_CASES_TEXT = """..."""
_HIDDEN_CASES = json.loads(base64.b64decode(_HIDDEN_CASES_TEXT).decode("utf-8"))

_RESULTS = {}

def _same_value(a, b):
    return a == b

def run_hidden_cases(qid, func):
    cases = _HIDDEN_CASES[qid]
    passed = 0
    for i, case in enumerate(cases, 1):
        args = case["args"]
        expected = case["expected"]
        try:
            result = func(*args)
        except Exception as e:
            print(f"❌ {qid} 第 {i} 筆測試發生錯誤：{type(e).__name__}: {e}")
            _RESULTS[qid] = False
            return False

        if _same_value(result, expected):
            passed += 1
        else:
            print(f"❌ {qid} 第 {i} 筆測試沒有通過")
            print("   輸入 args =", args)
            print("   你的結果 =", repr(result))
            print("   正確結果 =", repr(expected))
            _RESULTS[qid] = False
            return False

    print(f"✅ {qid} 通過！({passed}/{len(cases)})")
    _RESULTS[qid] = True
    return True

def summary():
    total = len(_HIDDEN_CASES)
    passed = sum(1 for q in _HIDDEN_CASES if _RESULTS.get(q) is True)
    print(f"目前通過：{passed} / {total}")
    missing = [q for q in _HIDDEN_CASES if _RESULTS.get(q) is not True]
    if missing:
        print("尚未通過或尚未檢查：", ", ".join(missing))
    else:
        print("🎉 全部通過！")

# %% [markdown]
# ## 先複習：`def` 函式作答方式
#
# 你會看到像這樣的格式：
#
# ```python
# def q1_hello_python():
#     # TODO: 回傳字串 Hello Python
#     pass
# ```
#
# 請把 `pass` 換成你的答案，例如：
#
# ```python
# def q1_hello_python():
#     return "Hello Python"
# ```
#
# `return` 是把結果交給檢查程式，不是印在畫面上。

# %%
# 範例：這不是正式題目，只是教你怎麼填答案

def example_name(name):
    return name

print(example_name("Amy"))
print(example_name("Bob"))

# %% [markdown]
# ## Q1. 點餐摘要：文字數字轉換與格式輸出
#
# `drink` 是品項名稱，`cups_text` 是杯數文字，`price_text` 是單價文字。
# 請先把杯數與單價轉成整數，計算總價後，回傳指定格式：`品項 x 杯數 = 總價元`。
#
# 範例：`q1_order_summary('奶茶', '2', '60')` 應該回傳 `'奶茶 x 2 = 120元'`。
#
# 請完成下面的函式。

# %%
def q1_order_summary(drink, cups_text, price_text):
    # TODO: 將 cups_text 和 price_text 轉成 int，計算總價後回傳指定格式
    pass

# %%
# 檢查本題：完成上面的函式後，執行這個 cell
q1_ok = run_hidden_cases("Q1", q1_order_summary)

# %% [markdown]
# ## Q2. print sep 概念：用符號連接
#
# 回傳三個地點，中間用 ` -> ` 連接。
#
# 範例：`q2_route('台北', '台中', '高雄')` 應該回傳 `'台北 -> 台中 -> 高雄'`。
#
# 請完成下面的函式。

# %%
def q2_route(city1, city2, city3):
    # TODO: 回傳 city1 -> city2 -> city3
    pass

# %%
# 檢查本題：完成上面的函式後，執行這個 cell
q2_ok = run_hidden_cases("Q2", q2_route)

# %% [markdown]
# ## Q3. input split 概念：拆名字與年齡
#
# `text` 會是一行資料，格式是 `名字 年齡`。請用 `split()` 的概念拆開，回傳 `名字:年齡`。
#
# 請完成下面的函式。

# %%
def q3_parse_student(text):
    # TODO: text 格式是 "名字 年齡"，回傳 "名字:年齡"
    pass

# %%
# 檢查本題：完成上面的函式後，執行這個 cell
q3_ok = run_hidden_cases("Q3", q3_parse_student)

# %% [markdown]
# ## Q4. 型態轉換：文字數字相加
#
# `a` 和 `b` 都是字串，例如 `'20'`。請先轉成整數，再回傳相加結果。
#
# 請完成下面的函式。

# %%
def q4_add_text_numbers(a, b):
    # TODO: a 和 b 是文字數字，請轉成 int 後相加
    pass

# %%
# 檢查本題：完成上面的函式後，執行這個 cell
q4_ok = run_hidden_cases("Q4", q4_add_text_numbers)

# %% [markdown]
# ## Q5. split + 多變數：交換位置與加總
#
# `pair_text` 會是一行兩個整數文字，例如 `'20 30'`。
# 請用 `split()` 拆開，轉成整數後，回傳 `[第二個數字, 第一個數字, 兩數相加]`。
#
# 範例：`q5_swap_and_sum('20 30')` 應該回傳 `[30, 20, 50]`。
#
# 請完成下面的函式。

# %%
def q5_swap_and_sum(pair_text):
    # TODO: 拆開 pair_text，轉成 int，回傳 [第二個數字, 第一個數字, 總和]
    pass

# %%
# 檢查本題：完成上面的函式後，執行這個 cell
q5_ok = run_hidden_cases("Q5", q5_swap_and_sum)

# %% [markdown]
# ## Q6. 多變數與 list：建立資料卡
#
# 把姓名、年齡、城市放進一個 list，回傳 `[name, age, city]`。
#
# 請完成下面的函式。

# %%
def q6_profile_card(name, age, city):
    # TODO: 回傳 [name, age, city]
    pass

# %%
# 檢查本題：完成上面的函式後，執行這個 cell
q6_ok = run_hidden_cases("Q6", q6_profile_card)

# %% [markdown]
# ## Q7. bool 混淆：空字串與文字 False
#
# 回傳 `bool(value)` 的結果。注意：文字 `'False'` 不是空的，所以結果是 `True`。
#
# 請完成下面的函式。

# %%
def q7_bool_check(value):
    # TODO: 回傳 bool(value)
    pass

# %%
# 檢查本題：完成上面的函式後，執行這個 cell
q7_ok = run_hidden_cases("Q7", q7_bool_check)

# %% [markdown]
# ## Q8. 序列：由上而下更新
#
# 請依照順序更新 `x`：先加 5，再乘以 2，最後回傳結果。
#
# 請完成下面的函式。

# %%
def q8_sequence_update(x):
    # TODO: 依序執行：x = x + 5，接著 x = x * 2，最後回傳 x
    pass

# %%
# 檢查本題：完成上面的函式後，執行這個 cell
q8_ok = run_hidden_cases("Q8", q8_sequence_update)

# %% [markdown]
# ## Q9. 括號優先順序
#
# 回傳 `(a + b) * c`，練習括號優先執行。
#
# 請完成下面的函式。

# %%
def q9_parentheses(a, b, c):
    # TODO: 回傳 (a + b) * c
    pass

# %%
# 檢查本題：完成上面的函式後，執行這個 cell
q9_ok = run_hidden_cases("Q9", q9_parentheses)

# %% [markdown]
# ## Q10. 除法分組：商數與餘數
#
# 有 `n` 位學生，每 `k` 位一班。請用 `//` 和 `%` 回傳指定格式：`班級數=商數,剩餘=餘數`。
#
# 請完成下面的函式。

# %%
def q10_group_students(n, k):
    # TODO: 回傳 "班級數=商數,剩餘=餘數"
    pass

# %%
# 檢查本題：完成上面的函式後，執行這個 cell
q10_ok = run_hidden_cases("Q10", q10_group_students)

# %% [markdown]
# ## Q11. 次方應用：正方形面積與邊框長度
#
# `side_text` 是正方形邊長的文字輸入。請轉成整數後，計算：
#
# - 面積：`side ** 2`
# - 邊框長度：`side * 4`
#
# 回傳指定格式：`area=面積,border=邊框長度`。
#
# 範例：`q11_square_info('5')` 應該回傳 `'area=25,border=20'`。
#
# 請完成下面的函式。

# %%
def q11_square_info(side_text):
    # TODO: 將 side_text 轉成 int，計算 area 和 border，回傳指定格式
    pass

# %%
# 檢查本題：完成上面的函式後，執行這個 cell
q11_ok = run_hidden_cases("Q11", q11_square_info)

# %% [markdown]
# ## Q12. 比較與型態轉換：及格判斷
#
# `score_text` 是輸入得到的文字分數。請轉成整數後判斷是否大於或等於 60。
#
# 請完成下面的函式。

# %%
def q12_pass_or_fail(score_text):
    # TODO: score_text 是文字，轉成 int 後，>= 60 回傳 True，否則 False
    pass

# %%
# 檢查本題：完成上面的函式後，執行這個 cell
q12_ok = run_hidden_cases("Q12", q12_pass_or_fail)

# %% [markdown]
# ## Q13. 邏輯運算：遊樂設施資格
#
# 身高至少 120 公分，而且年齡至少 10 歲，才可以搭乘。請用 `and` 完成判斷。
#
# 請完成下面的函式。

# %%
def q13_can_ride(height, age):
    # TODO: 身高 >= 120 而且 年齡 >= 10 才回傳 True
    pass

# %%
# 檢查本題：完成上面的函式後，執行這個 cell
q13_ok = run_hidden_cases("Q13", q13_can_ride)

# %% [markdown]
# ## Q14. 複合運算子概念：連續加分
#
# 把 `bonus1` 和 `bonus2` 依序加到 `score` 裡，回傳最後分數。可以用 `score += bonus1` 的想法。
#
# 請完成下面的函式。

# %%
def q14_bonus_score(score, bonus1, bonus2):
    # TODO: 用更新變數的想法，把兩次加分加到 score，回傳最後分數
    pass

# %%
# 檢查本題：完成上面的函式後，執行這個 cell
q14_ok = run_hidden_cases("Q14", q14_bonus_score)

# %% [markdown]
# ## Q15. 格式化輸出：小數與欄位寬度
#
# 回傳 `x` 的格式化字串：小數點後 2 位，且整體至少佔 6 個字元。
#
# 提示：可以使用 `%6.2f` 或 `format()`。
#
# 請完成下面的函式。

# %%
def q15_format_number(x):
    # TODO: 回傳 x 小數點後 2 位，且至少佔 6 個字元
    pass

# %%
# 檢查本題：完成上面的函式後，執行這個 cell
q15_ok = run_hidden_cases("Q15", q15_format_number)

# %% [markdown]
# ## Q16. 指定輸出格式：成績單
#
# 回傳指定格式：`Name:名字 | Score:分數.00`。分數要顯示到小數點後兩位。
#
# 請完成下面的函式。

# %%
def q16_report(name, score):
    # TODO: 回傳 "Name:名字 | Score:分數.00"
    pass

# %%
# 檢查本題：完成上面的函式後，執行這個 cell
q16_ok = run_hidden_cases("Q16", q16_report)

# %% [markdown]
# ## 總檢查
#
# 每一題都完成並執行檢查後，再執行下面這個 cell。

# %%
summary()
